# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تحلیل آماری داده‌ها
# </font>
# </h1>

# %% [markdown]
# <p dir="rtl" style="direction: rtl; text-align: justify; line-height: 2; font-family: Vazir, sans-serif; font-size: medium;">
#   <strong>خروجی نهایی</strong> باید شامل ۳۲ مقدار به شکل یک فایل
#   <code>submission.csv</code> با ۶ رقم اعشار باشد.
#   در هر بخش مقدار(های) لازم را در متغیرهای
#   <code>value_01</code> تا <code>value_32</code> قرار دهید.
#   در انتها این مقادیر استخراج و ذخیره می‌شوند.
# </p>
#
# <blockquote dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <strong>یادآوری:</strong> برای تمام محاسبات «وینسور» (Winsorization) روی هر سنسور به صورت مستقل انجام می‌دهیم:
#   برای هر سنسور صدک‌های ۱٪ و ۹۹٪ را با
#   <code>interpolation='linear'</code> محاسبه کرده و سپس با
#   <code>clip</code> مقادیر را به این بازه محدود می‌کنیم.
#   مگر جایی که صراحتاً گفته شده «خام/بدون وینسور». همچنین برای
#   <code>std</code> از نمونه‌ای (<code>ddof=1</code>) استفاده کنید.
# </blockquote>

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#
#   بارگذاری داده و آماده‌سازی
#      </font>
#
# </h1>
#
# <ul dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li>خواندن <code>sample.csv</code></li>
#   <li>تبدیل <code>timestamp</code> به نوع زمانی</li>
#   <li>تعریف تابع وینسور و نگهداشت نسخهٔ وینسورشدهٔ هر سنسور</li>
# </ul>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('statistical_analysis_data.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

SENSORS = ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']

def winsorize(s: pd.Series) -> pd.Series:
    q1 = s.quantile(0.01, interpolation='linear')
    q99 = s.quantile(0.99, interpolation='linear')
    return s.clip(lower=q1, upper=q99)

wdf = df.copy()
for c in SENSORS:
    wdf[c] = winsorize(wdf[c])

# %%
df.columns
# Out:
# Index(['timestamp', 'Temperature_C', 'Pressure_kPa', 'VibVelocity_mm_s',
#        'VibAccel_m_s2', 'FlowRate_L_min', 'Current_A', 'Voltage_V',
#        'Humidity_pct', 'pH_units', 'OilLevel_cm', 'Power_kW', 'Speed_RPM',
#        'Torque_Nm', 'BearingTemp_C', 'VibDisp_mm', 'status', 'RUL_seconds'],
#       dtype='object')

# %%
sum(wdf['Pressure_kPa'].dropna())
# Out:
# 373072.03679322917

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#      مقداردهی اولیهٔ متغیرهای پاسخ
#   </font>
# </h1>
#
# <p dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   در هر بخش متغیرهای <code>value_XX</code> را <strong>جایگزین/محاسبه</strong> کنید.
# </p>

# %%
value_01 = 60.461174
value_02 = 379.910424
value_03 = 27.760443
value_04 = 11.158711
value_05 = 4.007353
value_06 = 22.164835
value_07 = 2.256038
value_08 = 0.907363
value_09 = 51.770038
value_10 = 69.628905
value_11 = 332.542392
value_12 = 430.123253
value_13 = 22.93829
value_14 = 32.286874
value_15 = 9.07472
value_16 = 13.297109
value_17 = 0.579941
value_18 = 0.585990
value_19 = 0.592605
value_20 = 0.590642
value_21 = 0.555453
value_22 = 0.606897
value_23 = 60.352357
value_24 = 380.443519
value_25 = 27.811128
value_26 = 11.125979
value_27 = 0.586862
value_28 = 0.778221
value_29 = 0.960110
value_30 = 0.901485
value_31 = 0.279000
value_32 = 1.000000

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#     میانگین و انحراف معیار (وینسورشده)
#   </font>
# </h1>
#
# <ul dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li>مقادیر <strong>۱–۴</strong>: میانگین هر سنسور (به ترتیب: دما، فشار، شتاب ارتعاش، سرعت ارتعاش)</li>
#   <li>مقادیر <strong>۵–۸</strong>: انحراف معیار نمونه‌ای (<code>ddof=1</code>) به همان ترتیب</li>
# </ul>

# %%
# TODO: value_01 .. value_04 (means), value_05 .. value_08 (stds with ddof=1)
temperature = wdf['Temperature_C'].dropna();
value_01 = sum(temperature) / len(temperature)
value_01 = round(value_01, 6)
value_01
# Out:
# 60.461174

# %%
pressure = wdf['Pressure_kPa'].dropna();
value_02 = sum(pressure) / len(pressure)
value_02 = round(value_02, 6)
value_02
# Out:
# 379.910424

# %%
accel = wdf['VibAccel_m_s2'].dropna();
value_03 = sum(accel) / len(accel)
value_03 = round(value_03, 6)
value_03
# Out:
# 27.760443

# %%
speed = wdf['VibVelocity_mm_s'].dropna();
value_04 = sum(speed) / len(speed)
value_04 = round(value_04, 6)
value_04
# Out:
# 11.158711

# %%
temperature = wdf['Temperature_C'].dropna();
value_05 = np.std(temperature, ddof=1) 
value_05 = round(value_05, 6)
value_05
# Out:
# 4.007353

# %%
pressure = wdf['Pressure_kPa'].dropna();
value_06 = np.std(pressure, ddof=1) 
value_06 = round(value_06, 6)
value_06
# Out:
# 22.164835

# %%
accel = wdf['VibAccel_m_s2'].dropna();
value_07 = np.std(accel, ddof=1) 
value_07 = round(value_07, 6)
value_07
# Out:
# 2.256038

# %%
speed = wdf['VibVelocity_mm_s'].dropna();
value_08 = np.std(speed, ddof=1) 
value_08 = round(value_08, 6)
value_08
# Out:
# 0.907363

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#      کمینه و بیشینهٔ خام (بدون وینسور)
#   </font>
# </h1>
#
# <ul dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li>مقادیر <strong>۹–۱۶</strong>: به ترتیب <code>(min, max)</code> برای هر سنسور (دما، فشار، شتاب، سرعت)</li>
# </ul>

# %%
# TODO: value_09 .. value_16
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_09 = wdf['Temperature_C'].dropna().min()
value_09 = round(value_09,6)
value_09
# Out:
# 51.770038

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_10 = wdf['Temperature_C'].dropna().max()
value_10 = round(value_10,6)
value_10
# Out:
# 69.628905

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_11 = wdf['Pressure_kPa'].dropna().min()
value_11 = round(value_11,6)
value_11
# Out:
# 332.542392

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_12 = wdf['Pressure_kPa'].dropna().max()
value_12 = round(value_12,6)
value_12
# Out:
# 430.123253

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_13 = wdf['VibAccel_m_s2'].dropna().min()
value_13 = round(value_13,6)
value_13
# Out:
# 22.93829

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_14 = wdf['VibAccel_m_s2'].dropna().max()
value_14 = round(value_14,6)
value_14
# Out:
# 32.286874

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_15 = wdf['VibVelocity_mm_s'].dropna().min()
value_15 = round(value_15,6)
value_15
# Out:
# 9.07472

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_16 = wdf['VibVelocity_mm_s'].dropna().max()
value_16 = round(value_16,6)
value_16
# Out:
# 13.297109

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#     همبستگی پیرسون (وینسورشده، pairwise dropna)
#   </font>
# </h1>
#
# <p dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   مقادیر <strong>۱۷–۲۲</strong>: به ترتیب جفت‌ها
# </p>
#
# <ol dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li><code>(Temperature_C, Pressure_kPa)</code></li>
#   <li><code>(Temperature_C, VibAccel_m_s2)</code></li>
#   <li><code>(Temperature_C, VibVelocity_mm_s)</code></li>
#   <li><code>(Pressure_kPa, VibAccel_m_s2)</code></li>
#   <li><code>(Pressure_kPa, VibVelocity_mm_s)</code></li>
#   <li><code>(VibAccel_m_s2, VibVelocity_mm_s)</code></li>
# </ol>

# %%
# TODO: value_17 .. value_22
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_17_pd = wdf[["Temperature_C", "Pressure_kPa"]].dropna()
value_17 = wdf["Temperature_C"].corr(wdf["Pressure_kPa"], method="pearson")
value_17 = round(value_17,6)
value_17
# Out:
# 0.579941

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_18_pd = wdf[["Temperature_C", "VibAccel_m_s2"]].dropna()
value_18 = wdf["Temperature_C"].corr(wdf["VibAccel_m_s2"], method="pearson")
value_18 = round(value_18,6)
value_18
# Out:
# 0.58599

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_19_pd = wdf[["Temperature_C", "VibVelocity_mm_s"]].dropna()
value_19 = wdf["Temperature_C"].corr(wdf["VibVelocity_mm_s"], method="pearson")
value_19 = round(value_19,6)
value_19
# Out:
# 0.592605

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_20_pd = wdf[["Pressure_kPa", "VibAccel_m_s2"]].dropna()
value_20 = wdf["Pressure_kPa"].corr(wdf["VibAccel_m_s2"], method="pearson")
value_20 = round(value_20,6)
value_20
# Out:
# 0.590642

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_21_pd = wdf[["Pressure_kPa", "VibVelocity_mm_s"]].dropna()
value_21 = wdf["Pressure_kPa"].corr(wdf["VibVelocity_mm_s"], method="pearson")
value_21 = round(value_21,6)
value_21
# Out:
# 0.555453

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_22_pd = wdf[["VibAccel_m_s2", "VibVelocity_mm_s"]].dropna()
value_22 = wdf["VibAccel_m_s2"].corr(wdf["VibVelocity_mm_s"], method="pearson")
value_22 = round(value_22,6)
value_22
# Out:
# 0.606897

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#     میانهٔ هر سنسور (وینسورشده)
#   </font>
# </h1>
#
# <ul dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li>مقادیر <strong>۲۳–۲۶</strong>: میانهٔ سنسورها به ترتیب استاندارد</li>
# </ul>

# %%
# TODO: value_23 .. value_26
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_23 = wdf['Temperature_C'].dropna().median()
value_23 = round(value_23,6)
value_23
# Out:
# 60.352357

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_24 = wdf['Pressure_kPa'].dropna().median()
value_24 = round(value_24,6)
value_24
# Out:
# 380.443519

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_25 = wdf['VibAccel_m_s2'].dropna().median()
value_25 = round(value_25,6)
value_25
# Out:
# 27.811128

# %%
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_26 = wdf['VibVelocity_mm_s'].dropna().median()
value_26 = round(value_26,6)
value_26
# Out:
# 11.125979

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#     خودهمبستگی با وقفهٔ ۱ (lag=1) روی دادهٔ وینسورشده
#   </font>
# </h1>
#
# <ul dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li>مقادیر <strong>۲۷–۳۰</strong>: به ترتیب برای سنسورها</li>
# </ul>

# %%
# TODO: value_27 .. value_30
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_27 = wdf['Temperature_C'].dropna().autocorr(lag=1)
value_27 = round(value_27,6)
value_27
# Out:
# 0.586862

# %%
# TODO: value_27 .. value_30
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_28 = wdf['Pressure_kPa'].dropna().autocorr(lag=1)
value_28 = round(value_28,6)
value_28
# Out:
# 0.778221

# %%
# TODO: value_27 .. value_30
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_29 = wdf['VibAccel_m_s2'].dropna().autocorr(lag=1)
value_29 = round(value_29,6)
value_29
# Out:
# 0.96011

# %%
# TODO: value_27 .. value_30
#  ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_30 = wdf['VibVelocity_mm_s'].dropna().autocorr(lag=1)
value_30 = round(value_30,6)
value_30
# Out:
# 0.901485

# %% [markdown]
# <h1 dir="rtl" style="direction: rtl; text-align: right; font-family: Vazir, sans-serif; font-size: x-large; line-height: 2;">
#   <font face="vazir" color="#cc0000ff">
#    نرخ NaN و بازهٔ نمونه‌برداری
#   </font>
# </h1>
#
# <ul dir="rtl" style="direction: rtl; text-align: justify; font-family: Vazir, sans-serif; font-size: medium; line-height: 2;">
#   <li>مقدار <strong>۳۱</strong>: سهم ردیف‌هایی که <strong>حداقل یکی</strong> از چهار سنسورشان <code>NaN</code> دارد (روی دادهٔ خام)</li>
#   <li>مقدار <strong>۳۲</strong>: میانهٔ فاصلهٔ نمونه‌برداری (ثانیه) پس از مرتب‌سازی صعودی زمان‌ها</li>
# </ul>

# %%
# TODO: value_31 .. value_32
SENSORS = ['Temperature_C','Pressure_kPa','VibAccel_m_s2','VibVelocity_mm_s']
value_31_pd = df[SENSORS]
value_31 = df.isna().any(axis=1).sum() / len(df)
value_31 = round(value_31,6)
value_31
# Out:
# 0.279

# %%
mdf = df.copy().dropna()
mdf = mdf.sort_values(by="timestamp").reset_index(drop=True)
mdf["time_lag1"] = mdf["timestamp"].shift(1)
mdf["time_step"] = mdf["timestamp"] - mdf["time_lag1"]
median_step = mdf["time_step"].median()
median_step
# Out:
# Timedelta('0 days 00:00:01')

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) در غیر این صورت، در پایان مسابقه نمره شما به صفر تغییر خواهد کرد.
#     <br>
#     همچنین اگر از کولب برای اجرای این فایل نوت‌بوک استفاده می‌کنید، قبل از ارسال فایل <code>result.zip</code>، آخرین نسخه‌ی نوت‌بوک خود را دانلود کرده و داخل فایل ارسالی قرار دهید.
# </font>

# %%
import zipfile
import joblib
import os

if not os.path.exists(os.path.join(os.getcwd(), 'notebook.ipynb')):
    # %notebook -e notebook.ipynb

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

answers = [globals()[f'value_{i:02d}'] for i in range(1, 33)]
s = pd.Series(answers, dtype='float64', name="prediction")
s.to_csv("submission.csv", index=False, float_format="%.6f")

file_names = ['notebook.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['notebook.ipynb', 'submission.csv']
